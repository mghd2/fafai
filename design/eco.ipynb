# %%
from importlib import reload
import test_eco2
reload(test_eco2)
ai = test_eco2.StallForecaster()
test_ticks = 6000
sim = ai.test(test_ticks)
# Out:
# Stalling in 129 9999
# Making factory
# Making tank
# After builds stalling in 129 9999
# Current is 389.9000000000105 2498.0
# Stalling in 119 9999
# Making mex
# After builds stalling in 40 10
# Current is 359.8000000000117 2497.8999999999796
# Stalling in 34 6
# Making tank
# After builds stalling in 34 6
# Current is 328.3000000000125 2287.8999999999796
# Stalling in 38 3
# Making pgen
# Making pgen
# After builds stalling in 38 3
# Current is 305.8000000000131 2137.8999999999796
# Stalling in 20 1
# Making tank
# After builds stalling in 20 1
# Current is 162.80000000001388 795.8999999999764
# Stalling in 17 1
# Making pgen
# Making pgen
# After builds stalling in 17 1
# Current is 143.30000000001414 612.8999999999758
# Stalling in 0 0
# Making tank
# After builds stalling in 0 0
# Current is 6.488571433323375 4.1428570796142594e-08
# Stalling in 0 0
# Making mex
# Making mex
# After builds stalling in 0 0
# Current is 1.771428576180516 4.1428570796142594e-08
# Stalling in 0 4
# Making mex
# Making mex
# Making mex
# Making mex
# After builds stalling in 0 4
# Current is 1.8749999997069722e-08 2244.6250001639073
# Stalling in 9999 5
# Making pgen
# Making pgen
# Making pgen
# Making pgen
# Making pgen
# Making pgen
# Making pgen
# Making pgen
# After builds stalling in 9999 5
# Current is 2.4999999959085528e-08 2940.625000221965
# Stalling in 9999 4
# Making tank
# After builds stalling in 9999 4
# Current is 2.8846153909967143e-08 2748.463461797399
# Stalling in 9999 1
# Making pgen
# Making pgen
# Making pgen
# Making pgen
# Making pgen
# Making pgen
# Making pgen
# Making pgen
# After builds stalling in 9999 1
# Current is 2.8846153909967143e-08 413.4096156435079
# Stalling in 9999 2
# Making tank
# After builds stalling in 9999 2
# Current is 2.8846153909967143e-08 1095.2634617973558
# Stalling in 9999 16
# Making pgen
# Making pgen
# Making pgen
# Making pgen
# Making pgen
# Making pgen
# Making pgen
# Making pgen
# After builds stalling in 9999 16
# Current is 2.8846153909967143e-08 3985.576923076923
# Stalling in 9999 16
# Making tank
# After builds stalling in 9999 16
# Current is 2.8846153909967143e-08 3985.576923076923
# Stalling in 9999 50
# Making pgen
# Making pgen
# Making pgen
# Making pgen
# Making pgen
# Making pgen
# Making pgen
# Making pgen
# After builds stalling in 9999 50
# Current is 2.8846153909967143e-08 3985.576923076923
# Stalling in 9999 50
# Making tank
# After builds stalling in 9999 50
# Current is 2.8846153909967143e-08 3985.576923076923
# Stalling in 9999 9999
# Making factory
# Making factory
# Making factory
# Making factory
# Making factory
# Making factory
# Making factory
# Making factory
# After builds stalling in 9999 9999
# Current is 2.8846153909967143e-08 3985.576923076923
# Stalling in 9999 9999
# Making engy
# After builds stalling in 9999 9999
# Current is 2.2058823656578852e-08 3987.205882352941
# Stalling in 14 16
# Making tank
# Making mex
# After builds stalling in 14 16
# Current is 2.2058823656578852e-08 3987.205882352941
# Stalling in 2 15
# Making mex
# Making mex
# After builds stalling in 2 15
# Current is 2.1126760785250553e-08 3987.112676056338
# Stalling in 18 13
# Making pgen
# Making tank
# Making pgen
# Making tank
# Making pgen
# Making tank
# Making pgen
# Making tank
# Making pgen
# Making tank
# Making pgen
# Making tank
# Making pgen
# Making tank
# Making pgen
# Making tank
# After builds stalling in 18 13
# Current is 2.2077922157137664e-08 3985.2077922077924
# Stalling in 17 12
# Making tank
# After builds stalling in 17 12
# Current is 1.8279569857782008e-08 3986.2903225806454
# Stalling in 16 8
# Making pgen
# Making pgen
# After builds stalling in 16 8
# Current is 1.8279569857782008e-08 3986.2903225806454
# Stalling in 9999 16
# Making pgen
# Making pgen
# After builds stalling in 9999 16
# Current is 1.9191919164995852e-08 3984.4545454545455
# Stalling in 9999 51
# Making pgen
# Making pgen
# Making pgen
# Making pgen
# Making pgen
# Making pgen
# Making pgen
# Making pgen
# After builds stalling in 9999 51
# Current is 1.999999987845058e-08 3982.6
# Stalling in 9999 51
# Making tank
# Making tank
# Making tank
# Making tank
# Making tank
# Making tank
# Making tank
# Making tank
# After builds stalling in 9999 51
# Current is 1.999999987845058e-08 3982.6
# Stalling in 9999 51
# Making tank
# After builds stalling in 9999 51
# Current is 1.999999987845058e-08 3982.6
# Stalling in 9999 106
# Making factory
# Making factory
# After builds stalling in 9999 106
# Current is 1.999999987845058e-08 3982.6
# Stalling in 9999 9999
# Making factory
# After builds stalling in 9999 9999
# Current is 1.926605497359901e-08 3982.853211009174
# Stalling in 9999 9999
# Making factory
# Making factory
# Making factory
# Making factory
# Making factory
# Making factory
# Making factory
# Making factory
# After builds stalling in 9999 9999
# Current is 1.8918918875954205e-08 3982.972972972973
# Stalling in 9999 9999
# Making engy
# Making engy
# Making engy
# Making engy
# Making engy
# Making engy
# Making engy
# Making engy
# After builds stalling in 9999 9999
# Current is 1.653543302282401e-08 3983.7952755905512
# Stalling in 9999 9999
# Making engy
# After builds stalling in 9999 9999
# Current is 1.653543302282401e-08 3983.7952755905512

# %%
print("Stalled energy for", sim.e_stall_ticks)
print("Overflowed", sim.m_overflow_total, "mass")
print("Buildpower utilization (considering stalls)", int(100*(sim.commit_total / test_ticks)), "%")
print("Total spend:", sim.total_m_spend, "mass", sim.total_e_spend, "energy")
build_totals = {k:len(v) for (k, v) in sim.built_ticks.items()}
print("Built:", build_totals)
# Out:
# Stalled energy for 126
# Overflowed 0.10000000000002274 mass
# Buildpower utilization (considering stalls) 32 %
# Total spend: 8732.599999983631 mass 76182.29756674034 energy
# Built: {'landfac1': 9, 'nothing': 1, 'tank1': 27, 'mex1': 10, 'pgen1': 55, 'engy1': 1}

# %%
sim.plot_resources()
